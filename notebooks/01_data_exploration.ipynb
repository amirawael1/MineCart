# %%
# Milestone 1: Data Exploration
# Amazon QA Project - Initial Analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# NLP Project: Amazon Question Answering System
# ...
# Author: Amira Wael
# Milestone 1: Data Analysis
#
# 1. Dataset Overview:
# Shape: (100, 6)
# Columns: ['product_id', 'title', 'category', 'price', 'rating', 'review_count']
#
# 2. First 5 rows:
#   product_id             title     category       price    rating  \
# 0  PROD_0000  Amazon Product 0     Clothing  291.027465  4.633064
# 1  PROD_0001  Amazon Product 1         Home  233.664183  1.958248
# 2  PROD_0002  Amazon Product 2  Electronics  282.152188  1.579579
# 3  PROD_0003  Amazon Product 3     Clothing  268.974068  2.957811
# 4  PROD_0004  Amazon Product 4     Clothing  181.380494  4.942602
#
#    review_count
# 0           190
# 1           252
# 2           468
# 3           415
# 4           470
#
# 3. Basic Statistics:
#             price      rating  review_count
# count  100.000000  100.000000    100.000000
# mean   148.478781    3.066829    258.130000
# std     88.737552    1.193408    146.203722
# ...

# %%
print("NLP Project: Amazon Question Answering System")
print("="*60)
print("Author: Amira Wael | Khaled Ehab")
print("Milestone 1: Data Analysis")

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Create sample data for initial exploration
np.random.seed(42)
n_samples = 100

data = pd.DataFrame({
    'product_id': [f'PROD_{i:04d}' for i in range(n_samples)],
    'title': [f'Amazon Product {i}' for i in range(n_samples)],
    'category': np.random.choice(['Electronics', 'Books', 'Clothing', 'Home'], n_samples),
    'price': np.random.uniform(5, 300, n_samples),
    'rating': np.random.uniform(1, 5, n_samples),
    'review_count': np.random.randint(0, 500, n_samples)
})

# %%
print("\n1. Dataset Overview:")
print(f"Shape: {data.shape}")
print(f"Columns: {list(data.columns)}")

print("\n2. First 5 rows:")
print(data.head())

print("\n3. Basic Statistics:")
print(data.describe())

print("\n4. Missing Values:")
print(data.isnull().sum())

print("\n✅ Ready for Milestone 1 analysis!")
